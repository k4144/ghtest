# %%
import os,time,sys
import ghtest.param_suggestor as ps
from ghtest import make_test, scan, suggest
#ps.VB=1

# %%
# set print behavior
from IPython.display import display, Javascript
display(Javascript("""
document.querySelectorAll('.jp-OutputArea-child').forEach(e => e.style.maxHeight = 'none');
"""))

# %%
#src_folder='../temp_folder/src/apigh/'
src_folder='testdata'
#test_folder='../temp_folder/tests/'
scs=scan(src_folder)
#sct=scan(test_folder)

# %%
len(scs)#, len(sct)
# Out:
# 12

# %%
funcs=[f for f in scs if not f.qualname.startswith('_')]
#funcs=scs
for func in funcs:
    print(func.qualname )
    if 'checkpoint' in func.module:
        print(func)
# Out:
# get_commits
# list_repos
# create_repo
# delete_repo
# get_repo_data
# test_get_commits

# %%
func=funcs[2]
print(func.qualname)
[p for p in func.parameters if p.name=='user']
{k:v for k,v in func.module_globals.items() if 'user' in k}
[c for c in func.sample_calls if any('user' in k for k in c)]
[c for c in func.module_call_values if any('user' in k for k in c)]
{k:v for k,v in func.module_param_values.items() if 'user' in k}

#func.crud_role
#func.crud_resource
#[[(p.name, p.default) for p in f.parameters if 'user' in p.name] for f in func.module_functions]
#[f for f in [[(p.name, p.default) for p in f.parameters if p.default and 'k4144' in p.default] for f in func.module_functions] if f]
vars(func).keys()
keys=['module', 'qualname', 'filepath', 'lineno', 'parameters', 'returns', 'docstring', 'module_globals', 'sample_calls', 'module_call_values', 'module_param_values', 'crud_role', 'crud_resource', 'module_functions']
for k in keys:
    s=eval(f'func.{k}')
    if 'k4144' in str(s).lower():
        print(k)
if 'k4144' in str(func).lower():
    print('k4144')
# Out:
# create_repo

# %%
sp=suggest(func,test_functions=None, literal_only=True)
print(sp.module, sp.qualname)
for ps in sp.param_sets:
    print(ps)
# Out:
# gh_api create_repo
# {'name': 'coron', 'vb': 1, 'dry_run': False}
# {'name': 'coron6', 'vb': 2, 'dry_run': False}
# {'name': 'coron'}
# {'name': 'coron', 'user': 'gh4144'}
# {'name': 'coron', 'description': 'simple repo'}
# {'name': 'coron', 'private': True}
# {'name': 'coron', 'is_template': False}
# {'name': 'coron', 'dry_run': False}
# {'name': 'coron', 'dry_run': True}
# {'name': 'coron', 'vb': 0}
# {'name': 'coron', 'vb': 1}
# {'name': 'coron', 'vb': 2}

# %%
sp
# Out:
# SuggestedFunctionTests(module='gh_api', filepath='testdata/gh_api.py', qualname='create_repo', docstring=None, param_sets=[{'name': 'coron', 'vb': 1, 'dry_run': False}, {'name': 'coron6', 'vb': 2, 'dry_run': False}, {'name': 'coron'}, {'name': 'coron', 'user': 'gh4144'}, {'name': 'coron', 'description': 'simple repo'}, {'name': 'coron', 'private': True}, {'name': 'coron', 'is_template': False}, {'name': 'coron', 'dry_run': False}, {'name': 'coron', 'dry_run': True}, {'name': 'coron', 'vb': 0}, {'name': 'coron', 'vb': 1}, {'name': 'coron', 'vb': 2}], scenario=CrudScenario(resource='repo', identifier='repi0iqqo', steps=[ScenarioStep(module='gh_api', filepath='testdata/gh_api.py', qualname='get_repo_data', params={'name': 'repi0iqqo', 'dry_run': False}, expect='falsy', cleanup=False, description='Ensure resource does not exist before creation.'), ScenarioStep(module='gh_api', filepath='testdata/gh_api.py', qualname='create_repo', params={'name': 'repi0iqqo', 'dry_run': False}, expect='truthy', cleanup=False, description='Create resource instance.'), ScenarioStep(module='gh_api', filepath='testdata/gh_api.py', qualname='get_repo_data', params={'name': 'repi0iqqo', 'dry_run': False}, expect='truthy', cleanup=False, description='Validate resource exists after creation.'), ScenarioStep(module='gh_api', filepath='testdata/gh_api.py', qualname='delete_repo', params={'name': 'repi0iqqo', 'dry_run': False, 'force': True}, expect='truthy', cleanup=True, description='Delete the resource to leave no residue.'), ScenarioStep(module='gh_api', filepath='testdata/gh_api.py', qualname='get_repo_data', params={'name': 'repi0iqqo', 'dry_run': False}, expect='falsy', cleanup=False, description='Ensure resource is gone after deletion.')], note='Set GHTEST_ASSUME_SAFE=1 to skip confirmations before running this scenario.'))

# %%
cassette_dir='tests/cassettes'
gt=make_test(suggestion=sp, cassette_dir=cassette_dir)
success,max_attempts=0,2
removed=[]
while max_attempts and not success:
    max_attempts-=1
    from vcr.errors import CannotOverwriteExistingCassetteException
    try:
        tr=gt.test_callable()
        success=1
    except CannotOverwriteExistingCassetteException as e:
        #print(str(e))
        for name in os.listdir(cassette_dir):
            f=os.path.join(cassette_dir, name)
            if os.path.isfile(f):
                os.remove(f)
                removed.append(f)
print(f'success: {success}')
print(f'removed: {removed}')
#gt.cassette_path
#print(gt.source)
# Out:
# Planned CRUD scenario for resource 'repo' as 'repi0iqqo':
#   - get_repo_data(name='repi0iqqo', dry_run=False)
#   - create_repo(name='repi0iqqo', dry_run=False)
#   - get_repo_data(name='repi0iqqo', dry_run=False)
#   - delete_repo(name='repi0iqqo', dry_run=False, force=True)
#   - get_repo_data(name='repi0iqqo', dry_run=False)
# Note: Set GHTEST_ASSUME_SAFE=1 to skip confirmations before running this scenario.
# Proceed with the full sequence? [y/N]:  y
# Planned CRUD scenario for resource 'repo' as 'repi0iqqo':
#   - get_repo_data(name='repi0iqqo', dry_run=False)
#   - create_repo(name='repi0iqqo', dry_run=False)
#   - get_repo_data(name='repi0iqqo', dry_run=False)
#   - delete_repo(name='repi0iqqo', dry_run=False, force=True)
#   - get_repo_data(name='repi0iqqo', dry_run=False)
# Note: Set GHTEST_ASSUME_SAFE=1 to skip confirmations before running this scenario.
# Proceed with the full sequence? [y/N]:  y
# success: 1
# removed: ['tests/cassettes/gh_api.create_repo.yaml']

# %%
tr.cassette_path
#tr.cases
# Out:
# 'tests/cassettes/gh_api.create_repo.yaml'

# %%
for case in tr.cases:
    d=vars(case)
    for var in ('params', 'return_value', 'printed', 'exception'):
        r=d[var]
        if isinstance(r,list):
            print(var, len(r))
        else:
            print(var, r)
# Out:
# params {'name': 'coron', 'vb': 1, 'dry_run': False}
# return_value False
# printed error: name already exists on this account
#
# exception None
# params {'name': 'coron6', 'vb': 2, 'dry_run': False}
# return_value False
# printed {'Accept': 'application/vnd.github+json', 'X-GitHub-Api-Version': '2022-11-28', 'Content-Type': 'application/x-www-form-urlencoded', 'authorization': 'token github_pa..mU 99'}
# {"name": "coron6", "description": "simple repo allow_del_by_api=true ", "homepage": "https://github.com/gh4144/coron6", "private": true, "is_template": false}
# preparing request
# status 422
# error: name already exists on this account
#
# exception None
# params {'name': 'coron'}
# return_value None
# printed
# exception None
# params {'name': 'coron', 'user': 'gh4144'}
# return_value None
# printed
# exception None
# params {'name': 'coron', 'description': 'simple repo'}
# return_value None
# printed
# exception None
# params {'name': 'coron', 'private': True}
# return_value None
# printed
# exception None
# params {'name': 'coron', 'is_template': False}
# return_value None
# printed
# exception None
# params {'name': 'coron', 'dry_run': False}
# return_value False
# printed
# exception None
# params {'name': 'coron', 'dry_run': True}
# return_value None
# printed
# exception None
# params {'name': 'coron', 'vb': 0}
# return_value None
# printed
# exception None
# params {'name': 'coron', 'vb': 1}
# return_value None
# printed
# exception None
# params {'name': 'coron', 'vb': 2}
# return_value None
# printed {'Accept': 'application/vnd.github+json', 'X-GitHub-Api-Version': '2022-11-28', 'Content-Type': 'application/x-www-form-urlencoded', 'authorization': 'token github_pa..mU 99'}
# {"name": "coron", "description": "simple repo allow_del_by_api=true ", "homepage": "https://github.com/gh4144/coron", "private": true, "is_template": false}
#
# exception None
# params {'name': 'repi0iqqo', 'dry_run': False}
# return_value {}
# printed repi0iqqo not found
#
# exception None
# params {'name': 'repi0iqqo', 'dry_run': False}
# return_value True
# printed
# exception None
# params {'name': 'repi0iqqo', 'dry_run': False}
# return_value {'name': 'repi0iqqo', 'owner': 'gh4144', 'private': True, 'git_url': 'git://github.com/gh4144/repi0iqqo.git', 'ssh_url': 'git@github.com:gh4144/repi0iqqo.git'}
# printed
# exception None
# params {'name': 'repi0iqqo', 'dry_run': False, 'force': True}
# return_value True
# printed repi0iqqo deleted
#
# exception None
# params {'name': 'repi0iqqo', 'dry_run': False}
# return_value {}
# printed repi0iqqo not found
#
# exception None

# %%
vars(case).keys()
# Out:
# dict_keys(['target', 'params', 'return_value', 'printed', 'exception'])

# %%
tr1=gt.test_callable()
# Out:
# Planned CRUD scenario for resource 'repo' as 'repi0iqqo':
#   - get_repo_data(name='repi0iqqo', dry_run=False)
#   - create_repo(name='repi0iqqo', dry_run=False)
#   - get_repo_data(name='repi0iqqo', dry_run=False)
#   - delete_repo(name='repi0iqqo', dry_run=False, force=True)
#   - get_repo_data(name='repi0iqqo', dry_run=False)
# Note: Set GHTEST_ASSUME_SAFE=1 to skip confirmations before running this scenario.
# Proceed with the full sequence? [y/N]:  y

# %%
def check(tr1, tr2, vb=0):
    assert tr1.cassette_path==tr2.cassette_path
    cs1,cs2=tr1.cases,tr2.cases
    assert len(cs1)==len(cs2)
    for c1,c2 in zip(cs1,cs2):
        d1, d2=vars(c1), vars(c2)
        for var in ('params', 'return_value', 'printed', 'exception'):
            r1,r2=d1[var], d2[var]
            if isinstance(r1,list):
                if vb:print(var, len(r1))
            else:
                if vb:print(var, r1)
            if isinstance(r2,list):
                if vb:print(var, len(r2))
            else:
                if vb:print(var, r2)
            if isinstance(r1,list|dict|tuple) and isinstance(r2,list|dict|tuple):
                if vb:print('assert len')
                assert len(r1)==len(r2)
                if vb:print('assert identity')
                assert r1==r2

# %%
check(tr,tr1)

# %%
def print_value(v):
    if v is None:print(v)
    if isinstance(v,dict|list|tuple):
        print(f'len: {len(v)}')
    if isinstance(v,dict):
        print(f'keys: {v.keys()}')

# %%
for case in tr.cases:
    #print('#'*30)
    #print(case.target)
    #print(case.params)
    #print(case.printed)
    #print(case.exception)
    #print_value(case.return_value)
    
    #print()
    pass

# %%
vars(tr).keys()
# Out:
# dict_keys(['cassette_path', 'cases'])

# %%
print(gt.source)
# Out:
# import importlib
# import io
# import os
# from contextlib import redirect_stdout
# from dataclasses import dataclass
# from typing import Any, Dict, List, Optional
#
# import vcr
#
#
# @dataclass
# class TestCaseResult:
#     target: str
#     params: Dict[str, Any]
#     return_value: Any
#     printed: str
#     exception: Optional[BaseException]
#
#
# @dataclass
# class TestRunWithCassette:
#     cassette_path: str
#     cases: List[TestCaseResult]
#
#
# def _import_module_from_path(path: str, module_name: str = None) -> 'ModuleType':
#     """
#     Import a Python module directly from its file path.
#     Returns the loaded module object.
#     """
#     if module_name is None:
#         # Generate a unique name from the filename
#         import os, uuid
#         base = os.path.splitext(os.path.basename(path))[0]
#         module_name = f"{base}_{uuid.uuid4().hex}"
#
#     spec = importlib.util.spec_from_file_location(module_name, path)
#     if spec is None or spec.loader is None:
#         raise ImportError(f"cannot import module from {path}")
#
#     module = importlib.util.module_from_spec(spec)
#     sys.modules[module_name] = module
#     spec.loader.exec_module(module)
#     return module
#
#
# def _import_function(module: str, filepath: str, qualname: str) -> Callable[..., Any]:
#     try:
#         mod = importlib.import_module(module)
#     except Exception as e:
#         mod=_import_module_from_path(filepath)
#     obj: Any = mod
#     for part in qualname.split("."):
#         obj = getattr(obj, part)
#     return obj
#
#
# def test_create_repo() -> TestRunWithCassette:
#     module = 'gh_api'
#     filepath = 'testdata/gh_api.py'
#     qualname = 'create_repo'
#     cassette_dir = 'tests/cassettes'
#     cassette_name = 'gh_api.create_repo.yaml'
#     cassette_path = os.path.join(cassette_dir, cassette_name)
#     param_sets = [{'name': 'coron', 'vb': 1, 'dry_run': False}, {'name': 'coron6', 'vb': 2, 'dry_run': False}, {'name': 'coron'}, {'name': 'coron', 'user': 'gh4144'}, {'name': 'coron', 'description': 'simple repo'}, {'name': 'coron', 'private': True}, {'name': 'coron', 'is_template': False}, {'name': 'coron', 'dry_run': False}, {'name': 'coron', 'dry_run': True}, {'name': 'coron', 'vb': 0}, {'name': 'coron', 'vb': 1}, {'name': 'coron', 'vb': 2}]
#
#     os.makedirs(cassette_dir, exist_ok=True)
#
#     vcr_recorder = vcr.VCR(
#         serializer="yaml",
#         cassette_library_dir=cassette_dir,
#         record_mode='once',
#         match_on=["uri", "method"],
#     )
#
#     func = _import_function(module, filepath, qualname)
#     results: List[TestCaseResult] = []
#
#     with vcr_recorder.use_cassette(cassette_name):
#         for params in param_sets:
#             buf = io.StringIO()
#             with redirect_stdout(buf):
#                 try:
#                     ret = func(**params)
#                     exc: Optional[BaseException] = None
#                 except BaseException as e:
#                     ret = None
#                     exc = e
#             results.append(
#                 TestCaseResult(
#                     target=qualname,
#                     params=params,
#                     return_value=ret,
#                     printed=buf.getvalue(),
#                     exception=exc,
#                 )
#             )
#
#     return TestRunWithCassette(cassette_path=cassette_path, cases=results)

# %%
import importlib
import io
import os
from contextlib import redirect_stdout
from dataclasses import dataclass
from typing import Any, Dict, List, Optional, Callable

import vcr


@dataclass
class TestCaseResult:
    target: str
    params: Dict[str, Any]
    return_value: Any
    printed: str
    exception: Optional[BaseException]


@dataclass
class TestRunWithCassette:
    cassette_path: str
    cases: List[TestCaseResult]


def _import_module_from_path(path: str, module_name: str = None) -> 'ModuleType':
    """
    Import a Python module directly from its file path.
    Returns the loaded module object.
    """
    if module_name is None:
        # Generate a unique name from the filename
        import os, uuid
        base = os.path.splitext(os.path.basename(path))[0]
        module_name = f"{base}_{uuid.uuid4().hex}"

    spec = importlib.util.spec_from_file_location(module_name, path)
    if spec is None or spec.loader is None:
        raise ImportError(f"cannot import module from {path}")

    module = importlib.util.module_from_spec(spec)
    sys.modules[module_name] = module
    spec.loader.exec_module(module)
    return module


def _import_function(module: str, filepath: str, qualname: str) -> Callable[..., Any]:
    try:
        mod = importlib.import_module(module)
    except Exception as e:
        mod=_import_module_from_path(filepath)
    obj: Any = mod
    for part in qualname.split("."):
        obj = getattr(obj, part)    
    return obj


def test_create_repo() -> TestRunWithCassette:
    module = 'gh_api'
    filepath = 'testdata/gh_api.py'
    qualname = 'create_repo'
    cassette_dir = 'tests/cassettes'
    cassette_name = 'gh_api.create_repo.yaml'
    cassette_path = os.path.join(cassette_dir, cassette_name)
    param_sets = [{'name': 'coron', 'vb': 1, 'dry_run': False}, {'name': 'coron6', 'vb': 2, 'dry_run': False}, {'name': 'coron'}, {'name': 'coron', 'user': 'gh4144'}, {'name': 'coron', 'description': 'simple repo'}, {'name': 'coron', 'private': True}, {'name': 'coron', 'is_template': False}, {'name': 'coron', 'dry_run': False}, {'name': 'coron', 'dry_run': True}, {'name': 'coron', 'vb': 0}, {'name': 'coron', 'vb': 1}, {'name': 'coron', 'vb': 2}]

    os.makedirs(cassette_dir, exist_ok=True)

    vcr_recorder = vcr.VCR(
        serializer="yaml",
        cassette_library_dir=cassette_dir,
        record_mode='once',
        match_on=["uri", "method"],
    )

    func = _import_function(module, filepath, qualname)
    results: List[TestCaseResult] = []

    with vcr_recorder.use_cassette(cassette_name):
        for params in param_sets:
            buf = io.StringIO()
            with redirect_stdout(buf):
                try:
                    ret = func(**params)
                    exc: Optional[BaseException] = None
                except BaseException as e:
                    ret = None
                    exc = e
            results.append(
                TestCaseResult(
                    target=qualname,
                    params=params,
                    return_value=ret,
                    printed=buf.getvalue(),
                    exception=exc,
                )
            )

    return TestRunWithCassette(cassette_path=cassette_path, cases=results)

# %%
trwc=test_create_repo()

# %%
trwc
# Out:
# TestRunWithCassette(cassette_path='tests/cassettes/gh_api.create_repo.yaml', cases=[TestCaseResult(target='create_repo', params={'name': 'coron', 'vb': 1, 'dry_run': False}, return_value=False, printed='error: name already exists on this account\n', exception=None), TestCaseResult(target='create_repo', params={'name': 'coron6', 'vb': 2, 'dry_run': False}, return_value=False, printed='{\'Accept\': \'application/vnd.github+json\', \'X-GitHub-Api-Version\': \'2022-11-28\', \'Content-Type\': \'application/x-www-form-urlencoded\', \'authorization\': \'token github_pa..mU 99\'}\n{"name": "coron6", "description": "simple repo allow_del_by_api=true ", "homepage": "https://github.com/gh4144/coron6", "private": true, "is_template": false}\npreparing request\nstatus 422\nerror: name already exists on this account\n', exception=None), TestCaseResult(target='create_repo', params={'name': 'coron'}, return_value=None, printed='', exception=None), TestCaseResult(target='create_repo', params={'name': 'coron', 'user': 'gh4144'}, return_value=None, printed='', exception=None), TestCaseResult(target='create_repo', params={'name': 'coron', 'description': 'simple repo'}, return_value=None, printed='', exception=None), TestCaseResult(target='create_repo', params={'name': 'coron', 'private': True}, return_value=None, printed='', exception=None), TestCaseResult(target='create_repo', params={'name': 'coron', 'is_template': False}, return_value=None, printed='', exception=None), TestCaseResult(target='create_repo', params={'name': 'coron', 'dry_run': False}, return_value=False, printed='', exception=None), TestCaseResult(target='create_repo', params={'name': 'coron', 'dry_run': True}, return_value=None, printed='', exception=None), TestCaseResult(target='create_repo', params={'name': 'coron', 'vb': 0}, return_value=None, printed='', exception=None), TestCaseResult(target='create_repo', params={'name': 'coron', 'vb': 1}, return_value=None, printed='', exception=None), TestCaseResult(target='create_repo', params={'name': 'coron', 'vb': 2}, return_value=None, printed='{\'Accept\': \'application/vnd.github+json\', \'X-GitHub-Api-Version\': \'2022-11-28\', \'Content-Type\': \'application/x-www-form-urlencoded\', \'authorization\': \'token github_pa..mU 99\'}\n{"name": "coron", "description": "simple repo allow_del_by_api=true ", "homepage": "https://github.com/gh4144/coron", "private": true, "is_template": false}\n', exception=None)])

# %%
tr==trwc
# Out:
# False
